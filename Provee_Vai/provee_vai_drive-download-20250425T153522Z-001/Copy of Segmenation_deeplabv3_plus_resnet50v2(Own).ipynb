# %% [markdown]
# <h1 style="font-size:30px;">DeepLabv3+ with ResNet50_v2 Backbone</h1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q git+https://github.com/keras-team/keras-cv.git --upgrade
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 19.2 MB/s eta 0:00:00
#   Building wheel for keras-cv (pyproject.toml) ... done

# %%
import os
import requests
from zipfile import ZipFile
import glob
from dataclasses import dataclass, field

import random
import numpy as np
import cv2

import tensorflow as tf
import keras_cv

import matplotlib.pyplot as plt

# %% [markdown]
# ## Set Seeds for Reproducibility

# %%
def system_config(SEED_VALUE):
    # Set python `random` seed.
    # Set `numpy` seed
    # Set `tensorflow` seed.
    random.seed(SEED_VALUE)
    tf.keras.utils.set_random_seed(SEED_VALUE)
    os.environ["CUDA_VISIBLE_DEVICES"] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['TF_USE_CUDNN'] = "true"

system_config(SEED_VALUE=42)

# %% [markdown]
# ## Download and Extract Dataset

# %%
# Download and dataset.
def download_and_unzip(url, save_path):

    print("Downloading and extracting assets...", end="")
    file = requests.get(url)
    open(save_path, "wb").write(file.content)

    try:
        # Extract tarfile.
        if save_path.endswith(".zip"):
            with ZipFile(save_path) as zip:
                zip.extractall(os.path.split(save_path)[0])

        print("Done")
    except:
        print("Invalid file")

# %%
DATASET_URL = r"https://www.dropbox.com/scl/fi/9k8t9619b4x0hegued5c5/Water-Bodies-Dataset.zip?rlkey=tjgepcai6t74yynmx7tqsm7af&dl=1"
DATASET_DIR = "/content/drive/MyDrive/thesisB10/Water Bodies Dataset"
DATASET_ZIP_PATH = os.path.join(os.getcwd(), f"{DATASET_DIR}.zip")

# Download if dataset does not exists.
if not os.path.exists(DATASET_DIR):
    download_and_unzip(DATASET_URL, DATASET_ZIP_PATH)
    os.remove(DATASET_ZIP_PATH)

# %% [markdown]
# ## Configurations

# %% [markdown]
# ### Data Configuration

# %%
@dataclass(frozen=True)
class DatasetConfig:
    IMAGE_SIZE:        tuple = (256, 256)
    BATCH_SIZE:          int = 16
    NUM_CLASSES:         int = 2
    BRIGHTNESS_FACTOR: float = 0.2
    CONTRAST_FACTOR:   float = 0.2

# %% [markdown]
# ### Training Configuration

# %%
@dataclass(frozen=True)
class TrainingConfig:
    MODEL:           str = "resnet50_v2_imagenet"
    EPOCHS:          int = 100
    LEARNING_RATE: float = 1e-4
    CKPT_DIR:        str = os.path.join("/content/drive/MyDrive/thesisB10/resnet50v2/checkpoints",
                                        "deeplabv3_plus_"+"_".join(MODEL.split("_")[:2])+".weights.h5")
    LOGS_DIR:        str = "/content/drive/MyDrive/thesisB10/resnet50v2/logs_"+"_".join(MODEL.split("_")[:2])

# %%
train_config = TrainingConfig()
data_config = DatasetConfig()

# %% [markdown]
# ## Dataset Preparation

# %%
data_images = glob.glob(os.path.join(DATASET_DIR, "Images", "*.jpg"))
data_masks = glob.glob(os.path.join(DATASET_DIR, "Masks", "*.jpg"))

# Shuffle the data paths before data preparation.
zipped_data = list(zip(data_images, data_masks))
random.shuffle(zipped_data)
data_images, data_masks = zip(*zipped_data)
data_images = list(data_images)
data_masks = list(data_masks)

# %%
org_data = tf.data.Dataset.from_tensor_slices((data_images, data_masks))

# %% [markdown]
# ### Train-Validation Split

# %% [markdown]
# We are maintaining a **95-5** split ratio for training and validation samples respectively.

# %%
SPLIT_RATIO = 0.05
# Determine the number of validation samples
NUM_VAL = int(len(data_images) * SPLIT_RATIO)

# Split the dataset into train and validation sets
train_data = org_data.skip(NUM_VAL)
valid_data = org_data.take(NUM_VAL)

# %%
print(f"Train samples: {train_data.cardinality().numpy()}")
print(f"Validation samples: {valid_data.cardinality().numpy()}")
# Out:
# Train samples: 2699
# Validation samples: 142

# %% [markdown]
# ### Load Data and Threshold Masks

# %%
def read_image_mask(image_path, mask=False, size = data_config.IMAGE_SIZE):
    image = tf.io.read_file(image_path)

    if mask:
        image = tf.image.decode_jpeg(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=size, method = "bicubic")

        image_mask = tf.zeros_like(image)
        cond = image >=200
        updates = tf.ones_like(image[cond])
        image_mask = tf.tensor_scatter_nd_update(image_mask, tf.where(cond), updates)
        image = tf.cast(image_mask, tf.uint8)

    else:
        image = tf.image.decode_jpeg(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=size, method = "bicubic")
        image = tf.cast(tf.clip_by_value(image, 0., 255.), tf.float32)

    return image

# %%
def load_data(image_list, mask_list):
    image = read_image_mask(image_list)
    mask  = read_image_mask(mask_list, mask=True)
    return {"images":image, "segmentation_masks":mask}

# %%
train_ds = train_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# ### Unpack Images and Segmentation Masks
#
# The `unpackage_inputs` is a utility function that is used to unpack the inputs from the
# dictionary format to a tuple of `(images, segmentation_masks)`. This will be used later
# on for visualizing the images and segmentation masks and also the model predictions.

# %%
def unpackage_inputs(inputs):
    images = inputs["images"]
    segmentation_masks = inputs["segmentation_masks"]
    return images, segmentation_masks

# %% [markdown]
# ## Ground Truth Visualizations

# %%
# Dictionary mapping class IDs to colors.
id2color = {
    0: (0,  0,    0),    # Background
    1: (102, 204, 255),  # Waterbody
 }

# %%
# Function to convert a single channel mask representation to an RGB mask.
def num_to_rgb(num_arr, color_map=id2color):

    # single_layer = np.squeeze(num_arr)
    output = np.zeros(num_arr.shape[:2]+(3,))

    for k in color_map.keys():
        output[num_arr==k] = color_map[k]

    return output.astype(np.uint8)

# %%
# Function to overlay a segmentation map on top of an RGB image.
def image_overlay(image, segmented_image):

    alpha = 1.0 # Transparency for the original image.
    beta  = 0.7 # Transparency for the segmentation map.
    gamma = 0.0 # Scalar added to each sum.

    image = image.astype(np.uint8)

    segmented_image = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR)

    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    image = cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    return image

# %% [markdown]
# Let us display a few ground truth images along with the corresponding ground truth mask; and have it overlayed on the image input.

# %%
def display_image_and_mask(data_list, title_list, figsize, color_mask=False, color_map=id2color):

    # Create RGB segmentation map from grayscale segmentation map.
    rgb_gt_mask = num_to_rgb(data_list[1], color_map=color_map)
    mask_to_overlay = rgb_gt_mask

    if len(data_list)==3:
        rgb_pred_mask = num_to_rgb(data_list[-1], color_map=color_map)
        mask_to_overlay = rgb_pred_mask

    # Create the overlayed image.
    overlayed_image = image_overlay(data_list[0], mask_to_overlay)

    data_list.append(overlayed_image)

    fig, axes = plt.subplots(nrows=1, ncols=len(data_list), figsize=figsize)

    for idx, axis in enumerate(axes.flat):
        axis.set_title(title_list[idx])
        if title_list[idx] == "GT Mask":
            if color_mask:
                axis.imshow(rgb_gt_mask)
            else:
                axis.imshow(data_list[1], cmap="gray")

        elif title_list[idx] == "Pred Mask":
            if color_mask:
                axis.imshow(rgb_pred_mask)
            else:
                axis.imshow(data_list[-1], cmap="gray")

        else:
            axis.imshow(data_list[idx])

        axis.axis('off')

    plt.show()

# %%
plot_train_ds = train_ds.map(unpackage_inputs).batch(3)
image_batch, mask_batch = next(iter(plot_train_ds.take(1)))

titles = ["GT Image", "GT Mask", "Overlayed Mask"]

for image, gt_mask in zip(image_batch, mask_batch):

    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask],
                           title_list=titles,
                           figsize=(16,6),
                           color_mask=True)

# %% [markdown]
# ## Data Augmentation
#
# We will use the following transforms as augmentations:
# * RandomFlip (default mode is **"horizontal"**, with a probability of `0.5`)
# * Random Brightness
# * Random Contrast

# %%
augment_fn = tf.keras.Sequential(
    [
        keras_cv.layers.RandomFlip(),
        keras_cv.layers.RandomBrightness(factor=data_config.BRIGHTNESS_FACTOR,
                                         value_range=(0, 255)),
        keras_cv.layers.RandomContrast(factor=data_config.CONTRAST_FACTOR,
                                       value_range=(0, 255)),
    ]
)

# %%
train_dataset = (
                train_ds.shuffle(data_config.BATCH_SIZE)
                .map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)
                .batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

valid_dataset = (
                valid_ds.batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %% [markdown]
# Let's visualized a few images and their segmentation masks from the training data, with
# the `keras_cv.visualization.plot_segmentation_mask_gallery` API.

# %% [markdown]
# ### Visualize Augmented Data

# %%
image_batch, aug_mask_batch = next(iter(train_dataset.take(1)))

titles = ["GT Image", "GT Mask", "Overlayed Mask"]

for idx, (image, gt_mask) in enumerate(zip(image_batch, aug_mask_batch)):
    if idx > 1:
        break
    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask],
                           title_list=titles,
                           figsize=(16,6),
                           color_mask=False)

# %% [markdown]
# ## Model Architecture
#
# We will use `resnet50_v2_imagenet` feature extractor on top of the DeepLabv3 Head.

# %%
backbone = keras_cv.models.ResNet50V2Backbone.from_preset(preset = train_config.MODEL,
                                                          input_shape=data_config.IMAGE_SIZE+(3,),
                                                          load_weights = True)
model = keras_cv.models.segmentation.DeepLabV3Plus(
        num_classes=data_config.NUM_CLASSES, backbone=backbone,
    )
print(model.summary())
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/resnetv2/keras/resnet50_v2_imagenet/2/download/config.json...
# 100%|██████████| 886/886 [00:00<00:00, 2.12MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/resnetv2/keras/resnet50_v2_imagenet/2/download/model.weights.h5...
# 100%|██████████| 90.3M/90.3M [00:01<00:00, 49.6MB/s]
# Model: "deep_lab_v3_plus"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional (Functional)   │ [(None, 64, 64, 256),  │     23,556,608 │ input_layer[0][0]      │
# │                           │ (None, 8, 8, 2048)]    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_pyramid_pooling   │ (None, 8, 8, 256)      │     15,538,176 │ functional[0][1]       │
# │ (SpatialPyramidPooling)   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_output_upsampling │ (None, 64, 64, 256)    │              0 │ spatial_pyramid_pooli… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_7 (Sequential) │ (None, 64, 64, 48)     │         12,480 │ functional[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 64, 64, 304)    │              0 │ encoder_output_upsamp… │
# │                           │                        │                │ sequential_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential_8 (Sequential) │ (None, 256, 256, 2)    │         79,360 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 39,186,624 (149.49 MB)
#  Trainable params: 39,141,600 (149.31 MB)
#  Non-trainable params: 45,024 (175.88 KB)
# None

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# Intersection over Union (IoU) is a metric often used in segmentation problems to assess the model's accuracy. It provides a more intuitive basis for accuracy that is not biased by the (unbalanced) percentage of pixels from any particular class. Given two segmentation masks, `A` and `B`, the IoU is defined as follows:
#
# $$
# IoU = \frac{|A\cap B\hspace{1mm}|}{|A\cup B\hspace{1mm}|} \hspace{2mm}
# $$
#
# When there are multiple classes and inferences, we assess the model's performance by computing the mean IoU.
#
# The function below computes the mean IoU that only considers the classes that are present in the ground truth mask or the predicted segmentation map (sometimes referred to as classwise mean IoU). This computation is a better representation of the metric since it only considers the relevant classes. **This is the metric computation we use for mean IoU.**

# %%
def mean_iou(y_true, y_pred):

    # Get total number of classes from model output.
    num_classes = y_pred.shape[-1]

    y_true = tf.squeeze(y_true, axis=-1)

    y_true = tf.one_hot(tf.cast(y_true, tf.int32), num_classes, axis=-1)
    y_pred = tf.one_hot(tf.math.argmax(y_pred, axis=-1), num_classes, axis=-1)

    # Intersection: |G ∩ P|. Shape: (batch_size, num_classes)
    intersection = tf.math.reduce_sum(y_true * y_pred, axis=(1, 2))

    # Total Sum: |G| + |P|. Shape: (batch_size, num_classes)
    total = tf.math.reduce_sum(y_true, axis=(1, 2)) + tf.math.reduce_sum(y_pred, axis=(1, 2))

    union = total - intersection

    is_class_present =  tf.cast(tf.math.not_equal(total, 0), dtype=tf.float32)
    num_classes_present = tf.math.reduce_sum(is_class_present, axis=1)

    iou = tf.math.divide_no_nan(intersection, union)
    iou = tf.math.reduce_sum(iou, axis=1) / num_classes_present

    # Compute the mean across the batch axis. Shape: Scalar
    mean_iou = tf.math.reduce_mean(iou)

    return mean_iou

# %% [markdown]
# ### Tensorboard and ModelCheckpoint Callbacks

# %%
def get_callbacks(
    train_config,
    monitor="val_mean_iou",
    mode="max",
    save_weights_only=True,
    save_best_only=True,
):

    # Initialize tensorboard callback for logging.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=train_config.LOGS_DIR,
        histogram_freq=20,
        write_graph=False,
        update_freq="epoch",
    )


    # Update file path if saving best model weights.
    if save_weights_only:
        checkpoint_filepath = train_config.CKPT_DIR

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=save_weights_only,
        monitor=monitor,
        mode=mode,
        save_best_only=save_best_only,
        verbose=1,
    )

    return [tensorboard_callback, model_checkpoint_callback]

# %% [markdown]
# ## Train the model
#
# Now let's create the model, compile and train by calling `model.fit()` using the configurations defined in the `Trainingconfig` class.

# %%
# Build model.

# Get callbacks.
callbacks = get_callbacks(train_config)
# Define Loss.
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
# Compile model.
model.compile(
    optimizer=tf.keras.optimizers.Adam(train_config.LEARNING_RATE),
    loss=loss_fn,
    metrics=["accuracy", mean_iou],
)

# %%
# Train the model, doing validation at the end of each epoch.
history = model.fit(
    train_dataset,
    epochs=train_config.EPOCHS,
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5801 - loss: 0.7491 - mean_iou: 0.3705
# Epoch 1: val_mean_iou improved from -inf to 0.39548, saving model to /content/drive/MyDrive/thesisB10/resnet50v2/checkpoints/deeplabv3_plus_resnet50_v2.weights.h5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 914s 5s/step - accuracy: 0.5805 - loss: 0.7486 - mean_iou: 0.3707 - val_accuracy: 0.7022 - val_loss: 0.5893 - val_mean_iou: 0.3955
# Epoch 2/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6999 - loss: 0.5824 - mean_iou: 0.4355
# Epoch 2: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.6999 - loss: 0.5825 - mean_iou: 0.4355 - val_accuracy: 0.7135 - val_loss: 0.6082 - val_mean_iou: 0.3663
# Epoch 3/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7067 - loss: 0.5718 - mean_iou: 0.4389
# Epoch 3: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.7067 - loss: 0.5719 - mean_iou: 0.4388 - val_accuracy: 0.7190 - val_loss: 0.6046 - val_mean_iou: 0.3627
# Epoch 4/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7159 - loss: 0.5610 - mean_iou: 0.4435
# Epoch 4: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.7159 - loss: 0.5610 - mean_iou: 0.4434 - val_accuracy: 0.7153 - val_loss: 0.6091 - val_mean_iou: 0.3817
# Epoch 5/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7268 - loss: 0.5474 - mean_iou: 0.4497
# Epoch 5: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.7268 - loss: 0.5474 - mean_iou: 0.4497 - val_accuracy: 0.5060 - val_loss: 0.7555 - val_mean_iou: 0.3137
# Epoch 6/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7359 - loss: 0.5335 - mean_iou: 0.4528
# Epoch 6: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.7359 - loss: 0.5335 - mean_iou: 0.4528 - val_accuracy: 0.2817 - val_loss: 3.8441 - val_mean_iou: 0.1545
# Epoch 7/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7426 - loss: 0.5266 - mean_iou: 0.4545
# Epoch 7: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.7427 - loss: 0.5265 - mean_iou: 0.4545 - val_accuracy: 0.2817 - val_loss: 4.3628 - val_mean_iou: 0.1545
# Epoch 8/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7527 - loss: 0.5090 - mean_iou: 0.4613
# Epoch 8: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.7528 - loss: 0.5090 - mean_iou: 0.4613 - val_accuracy: 0.2817 - val_loss: 5.9108 - val_mean_iou: 0.1545
# Epoch 9/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7633 - loss: 0.4944 - mean_iou: 0.4692
# Epoch 9: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.7633 - loss: 0.4944 - mean_iou: 0.4692 - val_accuracy: 0.2817 - val_loss: 5.2092 - val_mean_iou: 0.1545
# Epoch 10/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7745 - loss: 0.4796 - mean_iou: 0.4791
# Epoch 10: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.7745 - loss: 0.4796 - mean_iou: 0.4791 - val_accuracy: 0.2817 - val_loss: 5.7670 - val_mean_iou: 0.1545
# Epoch 11/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7824 - loss: 0.4673 - mean_iou: 0.4871
# Epoch 11: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.7824 - loss: 0.4673 - mean_iou: 0.4871 - val_accuracy: 0.2817 - val_loss: 4.9471 - val_mean_iou: 0.1545
# Epoch 12/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7914 - loss: 0.4535 - mean_iou: 0.4977
# Epoch 12: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.7914 - loss: 0.4535 - mean_iou: 0.4977 - val_accuracy: 0.2817 - val_loss: 5.6931 - val_mean_iou: 0.1510
# Epoch 13/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7970 - loss: 0.4430 - mean_iou: 0.5061
# Epoch 13: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.7970 - loss: 0.4430 - mean_iou: 0.5061 - val_accuracy: 0.2817 - val_loss: 5.7108 - val_mean_iou: 0.1510
# Epoch 14/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8025 - loss: 0.4352 - mean_iou: 0.5165
# Epoch 14: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8024 - loss: 0.4352 - mean_iou: 0.5166 - val_accuracy: 0.2817 - val_loss: 5.7387 - val_mean_iou: 0.1545
# Epoch 15/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8075 - loss: 0.4256 - mean_iou: 0.5266
# Epoch 15: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8075 - loss: 0.4256 - mean_iou: 0.5266 - val_accuracy: 0.2812 - val_loss: 3.1468 - val_mean_iou: 0.1477
# Epoch 16/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8139 - loss: 0.4144 - mean_iou: 0.5401
# Epoch 16: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8139 - loss: 0.4144 - mean_iou: 0.5402 - val_accuracy: 0.2880 - val_loss: 2.6990 - val_mean_iou: 0.1534
# Epoch 17/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8154 - loss: 0.4105 - mean_iou: 0.5402
# Epoch 17: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8154 - loss: 0.4105 - mean_iou: 0.5402 - val_accuracy: 0.2819 - val_loss: 3.0041 - val_mean_iou: 0.1518
# Epoch 18/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8217 - loss: 0.3987 - mean_iou: 0.5584
# Epoch 18: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8217 - loss: 0.3987 - mean_iou: 0.5584 - val_accuracy: 0.2969 - val_loss: 2.6444 - val_mean_iou: 0.1617
# Epoch 19/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8297 - loss: 0.3861 - mean_iou: 0.5707
# Epoch 19: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.8297 - loss: 0.3861 - mean_iou: 0.5707 - val_accuracy: 0.3193 - val_loss: 1.7980 - val_mean_iou: 0.1773
# Epoch 20/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8354 - loss: 0.3749 - mean_iou: 0.5785
# Epoch 20: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.8354 - loss: 0.3749 - mean_iou: 0.5785 - val_accuracy: 0.3086 - val_loss: 2.3142 - val_mean_iou: 0.1682
# Epoch 21/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8399 - loss: 0.3652 - mean_iou: 0.5925
# Epoch 21: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - accuracy: 0.8399 - loss: 0.3652 - mean_iou: 0.5926 - val_accuracy: 0.3167 - val_loss: 1.8414 - val_mean_iou: 0.1752
# Epoch 22/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8456 - loss: 0.3546 - mean_iou: 0.6039
# Epoch 22: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.8456 - loss: 0.3546 - mean_iou: 0.6039 - val_accuracy: 0.3854 - val_loss: 1.3807 - val_mean_iou: 0.2334
# Epoch 23/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8472 - loss: 0.3507 - mean_iou: 0.6072
# Epoch 23: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.8472 - loss: 0.3507 - mean_iou: 0.6072 - val_accuracy: 0.3265 - val_loss: 1.7472 - val_mean_iou: 0.1861
# Epoch 24/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8503 - loss: 0.3441 - mean_iou: 0.6178
# Epoch 24: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.8503 - loss: 0.3441 - mean_iou: 0.6179 - val_accuracy: 0.4610 - val_loss: 1.2202 - val_mean_iou: 0.2932
# Epoch 25/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8565 - loss: 0.3334 - mean_iou: 0.6250
# Epoch 25: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8565 - loss: 0.3334 - mean_iou: 0.6250 - val_accuracy: 0.4619 - val_loss: 1.1272 - val_mean_iou: 0.2882
# Epoch 26/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8587 - loss: 0.3268 - mean_iou: 0.6322
# Epoch 26: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.8587 - loss: 0.3268 - mean_iou: 0.6322 - val_accuracy: 0.3470 - val_loss: 1.4956 - val_mean_iou: 0.2021
# Epoch 27/100
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8636 - loss: 0.3194 - mean_iou: 0.6416
# Epoch 27: val_mean_iou did not improve from 0.39548
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.8636 - loss: 0.3194 - mean_iou: 0.6416 - val_accuracy: 0.4844 - val_loss: 1.3267 - val_mean_iou: 0.3134
# Epoch 28/100
#  75/169 ━━━━━━━━━━━━━━━━━━━━ 1:43 1s/step - accuracy: 0.8642 - loss: 0.3180 - mean_iou: 0.6450

# %% [markdown]
# #### Load Fine-tuned Model Weights

# %%
model.load_weights(train_config.CKPT_DIR)

# %% [markdown]
# #### Perform Evaluation

# %%
evaluate = model.evaluate(valid_dataset)

# %% [markdown]
# ## Prediction with Fine-tuned Model
#
# Now that the model training of DeepLabv3 has been completed, let's test it by making predictions on a few sample images.

# %%
def inference(model, dataset, samples_to_plot):

    num_batches_to_process = 2
    count = 0
    stop_plot = False

    titles = ["Image", "GT Mask", "Pred Mask", "Overlayed Prediction"]

    for idx, data in enumerate(dataset):

        if stop_plot:
            break

        batch_img, batch_mask = data[0], data[1]
        batch_pred = (model.predict(batch_img)).astype('float32')
        batch_pred = batch_pred.argmax(axis=-1)

        batch_img  = batch_img.numpy().astype('uint8')
        batch_mask = batch_mask.numpy().squeeze(axis=-1)

        for image, mask, pred in zip(batch_img, batch_mask, batch_pred):
            count+=1
            display_image_and_mask([image, mask, pred],
                                  title_list=titles,
                                   figsize=(20,8),
                                   color_mask=True)
            if count >= samples_to_plot:
                stop_plot=True
                break

# %%
inference(model, valid_dataset, samples_to_plot=10)
